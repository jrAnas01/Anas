# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv("/content/IPL.csv")
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  22-05-2016       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016          Gujarat Lions
# 574  575    2016       Delhi  25-05-2016    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016          Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.head(23)
# Out:
#     id  season        city        date                        team1  \
# 0    1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 1    2    2008  Chandigarh  19-04-2008          Chennai Super Kings
# 2    3    2008       Delhi  19-04-2008             Rajasthan Royals
# 3    4    2008      Mumbai  20-04-2008               Mumbai Indians
# 4    5    2008     Kolkata  20-04-2008              Deccan Chargers
# 5    6    2008      Jaipur  21-04-2008              Kings XI Punjab
# 6    7    2008   Hyderabad  22-04-2008              Deccan Chargers
# 7    8    2008     Chennai  23-04-2008          Chennai Super Kings
# 8    9    2008   Hyderabad  24-04-2008              Deccan Chargers
# 9   10    2008  Chandigarh  25-04-2008              Kings XI Punjab
# 10  11    2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 11  12    2008     Chennai  26-04-2008        Kolkata Knight Riders
# 12  13    2008      Mumbai  27-04-2008               Mumbai Indians
# ...

# %%
df.tail(20)
# Out:
#       id  season           city        date                        team1  \
# 557  558    2016      Bangalore  11-05-2016  Royal Challengers Bangalore
# 558  559    2016      Hyderabad  12-05-2016          Sunrisers Hyderabad
# 559  560    2016  Visakhapatnam  13-05-2016               Mumbai Indians
# 560  561    2016      Bangalore  14-05-2016  Royal Challengers Bangalore
# 561  562    2016        Kolkata  14-05-2016      Rising Pune Supergiants
# 562  563    2016     Chandigarh  15-05-2016              Kings XI Punjab
# 563  564    2016  Visakhapatnam  15-05-2016               Mumbai Indians
# 564  565    2016        Kolkata  16-05-2016        Kolkata Knight Riders
# 565  566    2016  Visakhapatnam  17-05-2016             Delhi Daredevils
# 566  567    2016      Bangalore  18-05-2016  Royal Challengers Bangalore
# 567  568    2016         Kanpur  19-05-2016        Kolkata Knight Riders
# 568  569    2016         Raipur  20-05-2016          Sunrisers Hyderabad
# ...

# %%
df.shape
# Out:
# (577, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 572  False   False  False  False  False  False        False          False
# 573  False   False  False  False  False  False        False          False
# 574  False   False  False  False  False  False        False          False
# 575  False   False  False  False  False  False        False          False
# 576  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df['win_by_wickets'].fillna(df['win_by_wickets'].mean())
# Out:
# 0      0
# 1      0
# 2      9
# 3      5
# 4      5
#       ..
# 572    6
# 573    4
# 574    0
# 575    4
# 576    0
# Name: win_by_wickets, Length: 577, dtype: int64

# %%
df['win_by_wickets'].fillna(df['win_by_wickets'].median())
# Out:
# 0      0
# 1      0
# 2      9
# 3      5
# 4      5
#       ..
# 572    6
# 573    4
# 574    0
# 575    4
# 576    0
# Name: win_by_wickets, Length: 577, dtype: int64

# %%
df.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
sns.jointplot(x='toss_winner',y='result',data=df)

# %%
sns.barplot(x='win_by_runs',y='winner',data=df)
# Out:
# <Axes: xlabel='win_by_runs', ylabel='winner'>

# %%
result=df['result']
plt.plot(result)
plt.show()

# %%
toss_winner=df['toss_winner']
plt.plot(toss_winner)
plt.show()

# %%
sns.boxplot(x='win_by_runs',y='toss_winner',data=df)
# Out:
# <Axes: xlabel='win_by_runs', ylabel='toss_winner'>

# %%
sns.scatterplot(x='win_by_runs',y='win_by_wickets',data=df,hue='result')
# Out:
# <Axes: xlabel='win_by_runs', ylabel='win_by_wickets'>

# %%
sns.scatterplot(x='winner',y='result',data=df)
# Out:
# <Axes: xlabel='winner', ylabel='result'>

# %%
toss_winner=df['toss_winner']
plt.plot(toss_winner,color='red',label='toss_winner')
plt.legend()
plt.show()

# %%
win_by_runs=df['win_by_runs']
plt.plot(win_by_runs,color='purple',label='win_by_runs')
plt.legend()

# %%
win_by_wickets=df['win_by_wickets']
plt.plot(win_by_wickets,color='yellow',label='win_by_wickets')
plt.legend()

# %%
sns.pairplot(df)
plt.show()
